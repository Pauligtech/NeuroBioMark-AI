# %%
import sys, os
project_root = "/home/paul/alzheimers-mri-biomarker-agent"
sys.path.insert(0, project_root)

# %%
from agent_system.orchestration import run_pipeline

# %%
print(run_pipeline("S001", "T0"))
# Out:
# === MRI Biomarker Research Report ===
# Subject: S001
# Timepoint: T0
#
# Z-scores (relative to reference):
#   Hippocampal volume z:    -0.83
#   Ventricular volume z:    0.67
#   GM volume z:             -0.67
#   WM volume z:             -0.50
#
# Composite indices:
#   Ventricle / Hippocampus ratio: 3.88
#   Atrophy index (vent/ICV):      0.0087
#   GM/WM ratio:                   1.31
#
# Risk pattern (non-diagnostic):
#   Risk score: 1.05
#   Risk tier:  moderate
#
# Disclaimer: This is a research tool, not a clinical diagnosis or treatment system.

# %%
from agent_system.adk_orchestration import run_adk_style_pipeline

result = run_adk_style_pipeline("S001", "T0")
print(result["report_text"])
# Out:
# === MRI Biomarker Research Report ===
# Subject: S001
# Timepoint: T0
#
# Z-scores (relative to reference):
#   Hippocampal volume z:    -0.83
#   Ventricular volume z:    0.67
#   GM volume z:             -0.67
#   WM volume z:             -0.50
#
# Composite indices:
#   Ventricle / Hippocampus ratio: 3.88
#   Atrophy index (vent/ICV):      0.0087
#   GM/WM ratio:                   1.31
#
# Risk pattern (non-diagnostic):
#   Risk score: 1.05
#   Risk tier:  moderate
#
# Longitudinal summary:
#   subject_id: S001
# ...
